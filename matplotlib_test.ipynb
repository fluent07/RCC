# %%
import matplotlib.pyplot as plt
L = [5, 3, 6.2, 4.7]
# total = 0
total = sum(L)
x = [
    0,
    L[0],
    L[0],
    L[0] + L[1],
    L[0] + L[1],
    L[0] + L[1] + L[2],
    L[0] + L[1] + L[2],
    total
]
y = [-16.35, 23.64, -16.71, 7.28, -7.28, 11.31, -22.32, 15.27]
z = [0, total]
print(total)
a = [0, 0]
plt.plot(x, y, linewidth=0.5, color="r")
plt.plot(z, a, linewidth=5, color="k")
# Out:
# 18.9

# %%
A = [x1, x2, x3, x4, x5....., 1]
B = [y1, y2 ,y3 ,y4 ,y5,...., 1]
plt.plot(A,B)
